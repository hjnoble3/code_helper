# %%
import os
import re
from pathlib import Path


def find_api_endpoints(python_dir):
    """Find all API endpoints in Python files"""
    endpoints = {}
    patterns = [
        r'@(?:app|router)\.(get|post|put|delete|patch)\(["\']([^"\']+)["\']',
    ]

    for root, _, files in os.walk(python_dir):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        content = f.read()
                        for pattern in patterns:
                            matches = re.finditer(pattern, content)
                            for match in matches:
                                method = match.group(1)
                                path = match.group(2)
                                pattern_str = re.escape(path).replace(r'\{[^}]+}', r'[^/]+')
                                endpoints[path] = {
                                    'method': method,
                                    'file': file_path,
                                    'used': False,
                                    'pattern': re.compile(pattern_str),
                                    'core_path': path.strip('/')  # Store path without leading/trailing slashes
                                }
                except (IOError, UnicodeDecodeError) as e:
                    print(f"Warning: Could not read {file_path}: {e}")
    return endpoints


def search_in_ts_files(ts_dir, endpoints):
    """Search for endpoint usage in TypeScript files"""
    for root, _, files in os.walk(ts_dir):
        for file in files:
            if file.endswith(('.ts', '.svelte')):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        content = f.read()
                        for path, info in endpoints.items():
                            core_path = info['core_path']
                            # Extract the significant part of the path (after first parameter)
                            significant_path = re.sub(r'^[^/]+/', '', core_path)  # Remove anything before first param
                            if not significant_path:
                                significant_path = core_path  # Fallback to full path if no prefix

                            # Check multiple ways the endpoint might be used
                            if info['pattern'].search(content):
                                info['used'] = True
                            # Check template literal with any prefix plus significant path
                            elif re.search(f'`[^`]*{re.escape(significant_path)}[^`]*`', content):
                                info['used'] = True
                            # Check direct string usage with common prefixes
                            elif any(f'{quote}{prefix}{significant_path}{quote}' in content
                                     for quote in ['"', "'"]
                                     for prefix in ['', '/', 'users/', 'api/', '/users/', '/api/',
                                                    'functions/', '/functions/']):
                                info['used'] = True
                except (IOError, UnicodeDecodeError) as e:
                    print(f"Warning: Could not read {file_path}: {e}")


def main():
    # Configure these paths according to your project structure
    python_dir = './backend'  # Path to your Python backend directory
    ts_dir = './frontend'     # Path to your TypeScript/Svelte frontend directory

    # Find all API endpoints
    endpoints = find_api_endpoints(python_dir)

    # Search for their usage in TS files
    search_in_ts_files(ts_dir, endpoints)

    # Print results
    print("\nAPI Endpoints Analysis:")
    print("=====================")

    unused_endpoints = []
    used_endpoints = []

    for path, info in endpoints.items():
        if info['used']:
            used_endpoints.append((path, info))
        else:
            unused_endpoints.append((path, info))

    if used_endpoints:
        print("\nUsed Endpoints:")
        for path, info in sorted(used_endpoints):
            print(f"✓ {info['method'].upper()} {path} (in {info['file']})")

    if unused_endpoints:
        print("\nUnused Endpoints (potential candidates for removal):")
        for path, info in sorted(unused_endpoints):
            print(f"✗ {info['method'].upper()} {path} (in {info['file']})")
    else:
        print("\nNo unused endpoints found!")

    print(f"\nSummary:")
    print(f"Total endpoints: {len(endpoints)}")
    print(f"Used endpoints: {len(used_endpoints)}")
    print(f"Unused endpoints: {len(unused_endpoints)}")


if __name__ == "__main__":
    main()
# Out:
# API Endpoints Analysis:
# =====================
#
# Used Endpoints:
# ✓ GET / (in ./backend\webui_backend\routers\users.py)
# ✓ POST /add (in ./backend\webui_backend\routers\pipelines.py)
# ✓ POST /admin/config (in ./backend\webui_backend\routers\auths.py)
# ✓ GET /admin/details (in ./backend\webui_backend\routers\auths.py)
# ✓ DELETE /all (in ./backend\webui_backend\routers\files.py)
# ✓ GET /all/archived (in ./backend\webui_backend\routers\chats.py)
# ✓ GET /all/db (in ./backend\webui_backend\routers\chats.py)
# ✓ GET /all/tags (in ./backend\webui_backend\routers\chats.py)
# ✓ GET /api/changelog (in ./backend\webui_backend\main.py)
# ✓ POST /api/chat (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /api/chat/completed (in ./backend\webui_backend\main.py)
# ✓ POST /api/chat/completions (in ./backend\webui_backend\main.py)
# ✓ GET /api/config (in ./backend\webui_backend\main.py)
# ✓ POST /api/copy (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /api/create (in ./backend\webui_backend\routers\ollama.py)
# ✓ DELETE /api/delete (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /api/embed (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /api/generate (in ./backend\webui_backend\routers\ollama.py)
# ✓ GET /api/models (in ./backend\webui_backend\main.py)
# ✓ GET /api/models/base (in ./backend\webui_backend\main.py)
# ✓ GET /api/ps (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /api/pull (in ./backend\webui_backend\routers\ollama.py)
# ✓ DELETE /api/push (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /api/show (in ./backend\webui_backend\routers\ollama.py)
# ✓ GET /api/tags (in ./backend\webui_backend\routers\ollama.py)
# ✓ GET /api/tasks (in ./backend\webui_backend\main.py)
# ✓ GET /api/version (in ./backend\webui_backend\routers\ollama.py)
# ✓ GET /api/version/updates (in ./backend\webui_backend\main.py)
# ✓ POST /api/webhook (in ./backend\webui_backend\main.py)
# ✓ GET /api_key (in ./backend\webui_backend\routers\auths.py)
# ✓ POST /archive/all (in ./backend\webui_backend\routers\chats.py)
# ✓ GET /archived (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /audio/speech (in ./backend\webui_backend\routers\openai.py)
# ✓ POST /auto/completions (in ./backend\webui_backend\routers\tasks.py)
# ✓ GET /banners (in ./backend\webui_backend\routers\configs.py)
# ✓ GET /base (in ./backend\webui_backend\routers\models.py)
# ✓ POST /chat/completions (in ./backend\webui_backend\routers\openai.py)
# ✓ POST /code/execute (in ./backend\webui_backend\routers\utils.py)
# ✓ POST /code/format (in ./backend\webui_backend\routers\utils.py)
# ✓ POST /code_execution (in ./backend\webui_backend\routers\configs.py)
# ✓ GET /command/{command} (in ./backend\webui_backend\routers\prompts.py)
# ✓ GET /config (in ./backend\webui_backend\routers\tasks.py)
# ✓ POST /config/update (in ./backend\webui_backend\routers\tasks.py)
# ✓ GET /config/url/verify (in ./backend\webui_backend\routers\images.py)
# ✓ POST /create (in ./backend\webui_backend\routers\tools.py)
# ✓ GET /db/download (in ./backend\webui_backend\routers\utils.py)
# ✓ POST /default/permissions (in ./backend\webui_backend\routers\users.py)
# ✓ POST /delete (in ./backend\webui_backend\routers\retrieval.py)
# ✓ DELETE /delete/all (in ./backend\webui_backend\routers\models.py)
# ✓ DELETE /delete/user (in ./backend\webui_backend\routers\memories.py)
# ✓ POST /direct_connections (in ./backend\webui_backend\routers\configs.py)
# ✓ GET /ef (in ./backend\webui_backend\routers\memories.py)
# ✓ GET /ef/{text} (in ./backend\webui_backend\routers\retrieval.py)
# ✓ GET /embedding (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /embedding/update (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /emoji/completions (in ./backend\webui_backend\routers\tasks.py)
# ✓ GET /export (in ./backend\webui_backend\routers\tools.py)
# ✓ POST /feedback (in ./backend\webui_backend\routers\evaluations.py)
# ✓ DELETE /feedback/{id} (in ./backend\webui_backend\routers\evaluations.py)
# ✓ DELETE /feedbacks (in ./backend\webui_backend\routers\evaluations.py)
# ✓ DELETE /feedbacks/all (in ./backend\webui_backend\routers\evaluations.py)
# ✓ GET /feedbacks/all/export (in ./backend\webui_backend\routers\evaluations.py)
# ✓ GET /feedbacks/user (in ./backend\webui_backend\routers\evaluations.py)
# ✓ POST /generations (in ./backend\webui_backend\routers\images.py)
# ✓ GET /gravatar (in ./backend\webui_backend\routers\utils.py)
# ✓ GET /groups (in ./backend\webui_backend\routers\users.py)
# ✓ GET /health/db (in ./backend\webui_backend\main.py)
# ✓ GET /id/{id} (in ./backend\webui_backend\routers\tools.py)
# ✓ DELETE /id/{id}/delete (in ./backend\webui_backend\routers\tools.py)
# ✓ POST /id/{id}/toggle (in ./backend\webui_backend\routers\functions.py)
# ✓ POST /id/{id}/toggle/global (in ./backend\webui_backend\routers\functions.py)
# ✓ POST /id/{id}/update (in ./backend\webui_backend\routers\tools.py)
# ✓ GET /id/{id}/valves (in ./backend\webui_backend\routers\tools.py)
# ✓ GET /id/{id}/valves/spec (in ./backend\webui_backend\routers\tools.py)
# ✓ POST /id/{id}/valves/update (in ./backend\webui_backend\routers\tools.py)
# ✓ GET /id/{id}/valves/user (in ./backend\webui_backend\routers\tools.py)
# ✓ GET /id/{id}/valves/user/spec (in ./backend\webui_backend\routers\tools.py)
# ✓ POST /id/{id}/valves/user/update (in ./backend\webui_backend\routers\tools.py)
# ✓ GET /image/config (in ./backend\webui_backend\routers\images.py)
# ✓ POST /image/config/update (in ./backend\webui_backend\routers\images.py)
# ✓ POST /image_prompt/completions (in ./backend\webui_backend\routers\tasks.py)
# ✓ POST /import (in ./backend\webui_backend\routers\configs.py)
# ✓ GET /list (in ./backend\webui_backend\routers\tools.py)
# ✓ GET /litellm/config (in ./backend\webui_backend\routers\utils.py)
# ✓ POST /moa/completions (in ./backend\webui_backend\routers\tasks.py)
# ✓ GET /model (in ./backend\webui_backend\routers\models.py)
# ✓ DELETE /model/delete (in ./backend\webui_backend\routers\models.py)
# ✓ POST /model/toggle (in ./backend\webui_backend\routers\models.py)
# ✓ POST /model/update (in ./backend\webui_backend\routers\models.py)
# ✓ GET /models (in ./backend\webui_backend\routers\openai.py)
# ✓ POST /models/download (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /models/upload (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /new (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /pdf (in ./backend\webui_backend\routers\utils.py)
# ✓ GET /permissions (in ./backend\webui_backend\routers\users.py)
# ✓ GET /pinned (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /process/file (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /process/text (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /process/web (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /process/youtube (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /queries/completions (in ./backend\webui_backend\routers\tasks.py)
# ✓ POST /query (in ./backend\webui_backend\routers\memories.py)
# ✓ POST /query/collection (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /query/doc (in ./backend\webui_backend\routers\retrieval.py)
# ✓ GET /query/settings (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /query/settings/update (in ./backend\webui_backend\routers\retrieval.py)
# ✓ GET /reranking (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /reranking/update (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /reset (in ./backend\webui_backend\routers\memories.py)
# ✓ POST /reset/db (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /reset/uploads (in ./backend\webui_backend\routers\retrieval.py)
# ✓ GET /search (in ./backend\webui_backend\routers\chats.py)
# ✓ GET /share/{share_id} (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /signin (in ./backend\webui_backend\routers\auths.py)
# ✓ GET /signout (in ./backend\webui_backend\routers\auths.py)
# ✓ POST /signup (in ./backend\webui_backend\routers\auths.py)
# ✓ POST /speech (in ./backend\webui_backend\routers\audio.py)
# ✓ POST /suggestions (in ./backend\webui_backend\routers\configs.py)
# ✓ POST /tags (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /tags/completions (in ./backend\webui_backend\routers\tasks.py)
# ✓ GET /template (in ./backend\webui_backend\routers\retrieval.py)
# ✓ POST /title/completions (in ./backend\webui_backend\routers\tasks.py)
# ✓ POST /transcriptions (in ./backend\webui_backend\routers\audio.py)
# ✓ POST /update/password (in ./backend\webui_backend\routers\auths.py)
# ✓ POST /update/profile (in ./backend\webui_backend\routers\auths.py)
# ✓ POST /update/role (in ./backend\webui_backend\routers\users.py)
# ✓ POST /upload (in ./backend\webui_backend\routers\pipelines.py)
# ✓ GET /user/info (in ./backend\webui_backend\routers\users.py)
# ✓ POST /user/info/update (in ./backend\webui_backend\routers\users.py)
# ✓ GET /user/settings (in ./backend\webui_backend\routers\users.py)
# ✓ POST /user/settings/update (in ./backend\webui_backend\routers\users.py)
# ✓ POST /v1/chat/completions (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /v1/completions (in ./backend\webui_backend\routers\ollama.py)
# ✓ GET /v1/models (in ./backend\webui_backend\routers\ollama.py)
# ✓ POST /verify (in ./backend\webui_backend\routers\openai.py)
# ✓ GET /voices (in ./backend\webui_backend\routers\audio.py)
# ✓ GET /{id} (in ./backend\webui_backend\routers\knowledge.py)
# ✓ POST /{id}/archive (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /{id}/clone (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /{id}/clone/shared (in ./backend\webui_backend\routers\chats.py)
# ✓ GET /{id}/content (in ./backend\webui_backend\routers\files.py)
# ✓ GET /{id}/content/html (in ./backend\webui_backend\routers\files.py)
# ✓ GET /{id}/data/content (in ./backend\webui_backend\routers\files.py)
# ✓ POST /{id}/data/content/update (in ./backend\webui_backend\routers\files.py)
# ✓ DELETE /{id}/delete (in ./backend\webui_backend\routers\knowledge.py)
# ✓ POST /{id}/file/add (in ./backend\webui_backend\routers\knowledge.py)
# ✓ POST /{id}/file/remove (in ./backend\webui_backend\routers\knowledge.py)
# ✓ POST /{id}/file/update (in ./backend\webui_backend\routers\knowledge.py)
# ✓ POST /{id}/folder (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /{id}/pin (in ./backend\webui_backend\routers\chats.py)
# ✓ GET /{id}/pinned (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /{id}/reset (in ./backend\webui_backend\routers\knowledge.py)
# ✓ DELETE /{id}/share (in ./backend\webui_backend\routers\chats.py)
# ✓ DELETE /{id}/tags (in ./backend\webui_backend\routers\chats.py)
# ✓ POST /{id}/update (in ./backend\webui_backend\routers\knowledge.py)
# ✓ POST /{id}/update/expanded (in ./backend\webui_backend\routers\folders.py)
# ✓ POST /{id}/update/parent (in ./backend\webui_backend\routers\folders.py)
# ✓ POST /{memory_id}/update (in ./backend\webui_backend\routers\memories.py)
# ✓ GET /{pipeline_id}/valves (in ./backend\webui_backend\routers\pipelines.py)
# ✓ GET /{pipeline_id}/valves/spec (in ./backend\webui_backend\routers\pipelines.py)
# ✓ POST /{pipeline_id}/valves/update (in ./backend\webui_backend\routers\pipelines.py)
# ✓ POST /{user_id}/update (in ./backend\webui_backend\routers\users.py)
#
# Unused Endpoints (potential candidates for removal):
# ✗ POST /admin/config/ldap (in ./backend\webui_backend\routers\auths.py)
# ✗ POST /admin/config/ldap/server (in ./backend\webui_backend\routers\auths.py)
# ✗ POST /api/chat/actions/{action_id} (in ./backend\webui_backend\main.py)
# ✗ POST /api/chat/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/copy/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/create/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ DELETE /api/delete/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/embed/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/embeddings (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/embeddings/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/generate/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/pull/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ DELETE /api/push/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ GET /api/tags/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /api/tasks/stop/{task_id} (in ./backend\webui_backend\main.py)
# ✗ GET /api/version/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ DELETE /command/{command}/delete (in ./backend\webui_backend\routers\prompts.py)
# ✗ POST /command/{command}/update (in ./backend\webui_backend\routers\prompts.py)
# ✗ GET /folder/{folder_id} (in ./backend\webui_backend\routers\chats.py)
# ✗ GET /health (in ./backend\webui_backend\main.py)
# ✗ POST /ldap (in ./backend\webui_backend\routers\auths.py)
# ✗ GET /list/user/{user_id} (in ./backend\webui_backend\routers\chats.py)
# ✗ GET /manifest.json (in ./backend\webui_backend\main.py)
# ✗ POST /models/download/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /models/upload/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ GET /models/{url_idx} (in ./backend\webui_backend\routers\openai.py)
# ✗ GET /oauth/{provider}/callback (in ./backend\webui_backend\main.py)
# ✗ GET /oauth/{provider}/login (in ./backend\webui_backend\main.py)
# ✗ GET /opensearch.xml (in ./backend\webui_backend\main.py)
# ✗ POST /process/files/batch (in ./backend\webui_backend\routers\retrieval.py)
# ✗ POST /process/web/search (in ./backend\webui_backend\routers\retrieval.py)
# ✗ POST /v1/chat/completions/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ POST /v1/completions/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ GET /v1/models/{url_idx} (in ./backend\webui_backend\routers\ollama.py)
# ✗ GET /{id}/content/{file_name} (in ./backend\webui_backend\routers\files.py)
# ✗ POST /{id}/files/batch/add (in ./backend\webui_backend\routers\knowledge.py)
# ✗ DELETE /{id}/tags/all (in ./backend\webui_backend\routers\chats.py)
# ✗ DELETE /{memory_id} (in ./backend\webui_backend\routers\memories.py)
# ✗ DELETE /{user_id} (in ./backend\webui_backend\routers\users.py)
#
# Summary:
# Total endpoints: 201
# Used endpoints: 162
# Unused endpoints: 39
